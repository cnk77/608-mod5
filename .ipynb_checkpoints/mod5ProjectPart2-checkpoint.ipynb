# %%
# Module 5 Project Part 2

# Kyle Hudson

# Follow the instructions in 7.14.2 to import pandas as pd and create a pandas DataFrame from a dictionary (a set of key-value pairs) 
# holding multiple exam scores for each key/student. In this example, we have 5 students, each with 3 exam scores, but the scores aren't labeled.

import pandas as pd

grades_dict = {'Wally': [87, 96, 70], 'Eva': [100, 87, 90], 'Sam': [94, 77, 90], 'Katie': [100, 81, 82], 'Bob': [83, 65, 85]}

grades = pd.DataFrame(grades_dict)

print(grades)

# Follow the instructions to apply a custom index (instead of 0,1,2), let's call them 'Test1', Test2', and 'Test3'. See 'Customizing a 
# DataFrame's Indices with the index Attribute subsection. 

grades.index = ['Test1', 'Test2', 'Test3']

print(grades)

# As we did in Part 1, we can request grades by key using the text attribute (square brackets with single quoted text strings). 
# Find Eva's grades with grades['Eva'] 

print(grades['Eva'])

# If no spaces in the key, we can use the simpler dot attribute approach. Find Sam's grades with grades.Sam as shown 
# in 'Accessing a DataFrame's columns' subsection.

print(grades.Sam)

# Like spreadsheets, we can access specific rows or columns. Execute the examples using loc['Test1'] to get scores for the first exam, 
# or iLoc[0] to get scores for the first exam and iLoc[1] to get scores for the second exam. Which do you prefer?

print(grades.loc['Test1']) # I prefer using the index name instead of the location, it just makes more sense to me
print(grades.iloc[0])
print(grades.iloc[1])

# Use grades.at['Test2', 'Eva'} to find her score on the second exam.

print(f"Eva's grade on Test 2 is", grades.loc['Test2', 'Eva'])

# Use grades.iat[2,0] to get the score on the third exam for the first student (Wally).

print(f"Wally's grade on Test 3 is", grades.iat[2, 0])

# Use grades.describe() to get descriptive statistics for our gradebook. 

pd.set_option('precision', 2)

print(grades.describe())

# Get the average score for each student key by calling grades.mean()

print(grades.mean())

# Sort the gradebook rows in reverse order so the most recent exam row appears at the top with grades.sort_index(ascending=False)

print(grades.sort_index(ascending=False))

# Sort the gradebook columns so the names appear in order using grades.sort_index(axis=1).

print(grades.sort_index(axis=1))
# Out:
#    Wally  Eva  Sam  Katie  Bob
# 0     87  100   94    100   83
# 1     96   87   77     81   65
# 2     70   90   90     82   85
#        Wally  Eva  Sam  Katie  Bob
# Test1     87  100   94    100   83
# Test2     96   87   77     81   65
# Test3     70   90   90     82   85
# Test1    100
# Test2     87
# Test3     90
# Name: Eva, dtype: int64
# Test1    94
# Test2    77
# Test3    90
# Name: Sam, dtype: int64
# Wally     87
# Eva      100
# Sam       94
# Katie    100
# Bob       83
# Name: Test1, dtype: int64
# Wally     87
# Eva      100
# Sam       94
# Katie    100
# Bob       83
# Name: Test1, dtype: int64
# Wally    96
# Eva      87
# Sam      77
# Katie    81
# Bob      65
# Name: Test2, dtype: int64
# Eva's grade on Test 2 is 87
# Wally's grade on Test 3 is 70
#        Wally     Eva    Sam   Katie    Bob
# count   3.00    3.00   3.00    3.00   3.00
# mean   84.33   92.33  87.00   87.67  77.67
# std    13.20    6.81   8.89   10.69  11.02
# min    70.00   87.00  77.00   81.00  65.00
# 25%    78.50   88.50  83.50   81.50  74.00
# 50%    87.00   90.00  90.00   82.00  83.00
# 75%    91.50   95.00  92.00   91.00  84.00
# max    96.00  100.00  94.00  100.00  85.00
# Wally    84.33
# Eva      92.33
# Sam      87.00
# Katie    87.67
# Bob      77.67
# dtype: float64
#        Wally  Eva  Sam  Katie  Bob
# Test3     70   90   90     82   85
# Test2     96   87   77     81   65
# Test1     87  100   94    100   83
#        Bob  Eva  Katie  Sam  Wally
# Test1   83  100    100   94     87
# Test2   65   87     81   77     96
# Test3   85   90     82   90     70
